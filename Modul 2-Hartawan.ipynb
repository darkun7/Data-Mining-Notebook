# %% [markdown]
# # Module 2 Praktikum Data Mining
# ## Eksplorasi data menggunakan matplotlib
# * Hartawan Bahari Mulyadi
# * Student ID: 182410101113

# %%
# Init Library
import matplotlib.pyplot as plt
import numpy as np

from google.colab import drive
drive.mount('/content/gdrive')
#!ls /content/gdrive/My\ Drive/Tugas/datmin/
import sys
sys.path.append('/content/gdrive/My Drive/Tugas/datmin')
import pretty_print as ptag
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# ### KODE 1

# %%
xpoints = np.array([0, 6])   #line 4
ypoints = np.array([0, 250]) #line 5
plt.plot(xpoints, ypoints)   #line 6
plt.show()                   #line 7

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
# a.	Jelaskan fungsi dari library matplotlib. Jelaskan tentang plyplot
# b.	Sebutkan koordinat yang akan digambar oleh kode baris 4 – 5
# c.	Apa fungsi kode baris 6 
# d.	Apa fungsi kode baris 7
# e.	Gantilah baris 6 dengan plt.plot(xpoints, ypoints, 'o'). jelaskan apa yang terjadi
plt.plot(xpoints, ypoints, 'ro')
plt.show()
# f.	Plotlah koordinat berikut (7,11),(10,5),(11,15),(14,2),(17,1),(17,11),(19,4),(20,20)  dengan garis
x = np.array([7,10,11,14,17,17,19,20])
y = np.array([11,5,15,2,1,11,4,20])
plt.plot(x, y,marker='o', linestyle='dashed')
plt.show()

# g.	Plotlah koordinat berikut (7,11),(10,5),(11,15),(14,2),(17,1),(17,11),(19,4),(20,20)  tanpa garis
x = np.array([7,10,11,14,17,17,19,20])
y = np.array([11,5,15,2,1,11,4,20])
plt.plot(x, y,marker='o')
plt.show()

#Experimental
#plot(x, y, color='green', marker='o', linestyle='dashed', linewidth=2, markersize=12)

# %% [markdown]
# ### KODE 2

# %%
ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink') #line 5
plt.show()

ypoints = np.array([3, 8, 1, 10])
plt.plot(ypoints, color = 'r', ls = '--', linewidth = '5')
plt.show()

x1 = np.array([0, 1, 2, 3])   #line 12
y1 = np.array([3, 8, 1, 10])  #line 13
x2 = np.array([0, 1, 2, 3])   #line 14
y2 = np.array([6, 2, 7, 11])  #line 15
plt.plot(x1, y1, x2, y2)      #line 16
plt.show()                    #line 17

# %%
# a.	Jelaskan fungsi dari baris 5. Jelaskan makna parameter ms, mec, mfc 
# b.	Plotlah koordinat berikut (7,11),(10,5),(11,15),(14,2),(17,1),(17,11),(19,4),(20,20) dengan marker star, 
#     ukuran marker 15, warna tepi marker biru, warna area dalam marker kuning  
x = np.array([7,10,11,14,17,17,19,20])
y = np.array([11,5,15,2,1,11,4,20])
plt.plot(x,y, marker='*', ms='15', mec='b', mfc='y')
plt.show()
# c.	Jelaskan fungsi baris 9. Jelaskan makna parameter color. Ls, linewidth
# d.	Plotlah koordinat berikut (7,11),(10,5),(11,15),(14,2),(17,1),(17,11),(19,4),(20,20) 
#     dengan garis warna kuning ukuran 5 dengan style garis penuh
x = np.array([7,10,11,14,17,17,19,20])
y = np.array([11,5,15,2,1,11,4,20])
plt.plot(x,y , c='y',lw='5',ls ='-')
plt.show()
# e.	Jelaskan kode baris 12 – 17
# f.	Plotlah koordinat berikut (7,11),(10,5),(11,15),(14,2),(17,1),(17,11),(19,4),(20,20). 
#     Kemudian tambahkan koordinat yang posisinya 1 satuan di atas koordinat awal. 
#     Kemudian tambahkan koordinat yang posisinya 2 satuan di kanan koordinat awal.
x1 = x+2
y1 = y+1
# ptag.sep("awal")
# plt.plot(x, y)
# plt.show()
# ptag.sep("#1")
# plt.plot(x, y, x,y1)
# plt.show()
# ptag.sep("#2")
# plt.plot(x, y, x1,y1)
# plt.show()

# plt.plot(x, y)
# plt.plot(x, y, x,y1)
plt.plot(x, y, x,y1, x1,y1)
plt.show()

# %% [markdown]
# ### KODE 3

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

font1 = {'family':'serif','color':'blue','size':20}       #line 7
font2 = {'family':'serif','color':'darkred','size':15}    #line 8

plt.title("Sports Watch Data", fontdict = font1)          #line 10
plt.xlabel("Average Pulse", fontdict = font2)             #line 11
plt.ylabel("Calorie Burnage", fontdict = font2)           #line 12

plt.plot(x, y)
plt.show()

#plot 1:                        #line 17
x = np.array([0, 1, 2, 3])      #line 18
y = np.array([3, 8, 1, 10])     #line 19

plt.subplot(1, 2, 1)            #line 21
plt.plot(x,y)                   #line 22

#plot 2:
x = np.array([0, 1, 2, 3])      #line 25
y = np.array([10, 20, 30, 40])  #line 26

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.show()

# %%
# a.	Jelaskan fungsi dari baris 7 – 12
# b.	Plotlah koordinat berikut (7,11),(10,5),(11,15),(14,2),(17,1),(17,11),(19,4),(20,20). 
#     Beri keterangan sumbu X : nilai mendatar, sumbu Y : nilai vertikal, dan judul : latihan. Untuk judul dan sumbu Y  gunakan font 1. 
#     Untuk sumbu X gunakan font 2 
x = np.array([7,10,11,14,17,17,19,20])
y = np.array([11,5,15,2,1,11,4,20])
plt.xlabel("nilai mendatar", fontdict = font2)
plt.ylabel("nilai vertikal", fontdict = font1)
plt.title("latihan", fontdict = font1)
plt.plot(x, y)
plt.show()

# c.	Jelaskan fungsi dari baris 18 – 22  
# d.	Plotlah koordinat berikut (7,11),(10,5),(11,15),(14,2),(17,1),(17,11),(19,4),(20,20) di subplot 1.
#     Koordinat yang posisinya 1 satuan di atas koordinat awal di subplot 2.
#     Koordinat yang posisinya 1 satuan di atas koordinat awal di subplot 3. 
# apakah plotnya 1x3? lalu kok sama 1 satuan?
#ALTERNATIF
ptag.sep("CARA ALTERNATIF")
fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
fig.suptitle('Cara Alternatif')
ax1.plot(x, y)
ax2.plot(x, y+1)
ax3.plot(x, y+1)
plt.show()

#MODUL
ptag.sep("CARA SESUAI MODUL")
plt.suptitle("Cara Sesuai Modul")
plt.subplot(1, 3, 1)
plt.plot(x,y)
plt.subplot(1, 3, 2)
plt.plot(x,y+1)
plt.subplot(1, 3, 3)
plt.plot(x,y+1)
plt.show()
# Out:
# =-=-=-=-=-=[CARA ALTERNATIF]=-=-=-=-=-=
# =-=-=-=-=-=[CARA SESUAI MODUL]=-=-=-=-=-=

# %% [markdown]
# ### KODE 4

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

plt.show()

# %%
# a.	Jelaskan fungsi dari baris 4 – 12
# b.	Plotlah koordinat berikut (7,11),(10,5),(11,15),(14,2),(17,1),(17,11),(19,4),(20,20) 
#     dalam bentuk scatter plot. Dan koordinat yang posisinya 1 satuan di atas koordinat awal sebagai scatterplot yang berbeda. 
x = np.array([7,10,11,14,17,17,19,20])
y = np.array([11,5,15,2,1,11,4,20])
plt.scatter(x, y, color = '#4B6858')
plt.scatter(x, y+1, color = '#46ACC2')
plt.show()

# %% [markdown]
# # TUGAS
# 1.	Jelaskan makna dataset. Jelaskan pula makna data training dan data testing
# 2.	Jelaskan proses penyusunan dataset
# 3.	Jelaskan makna attribut dataset iris. Jelaskan pula makna kelas dataset iris
# 4.	Masukkan dataset iris sebagai array 2D di numpy. Pisahkan setiap kelas di array yang berbeda : setosa, versicolor, virginica, dan unknown
# 5.	Buatlah scatter plot yang menggunakan pasangan attribut berikut pada setiap kelas (termasuk unknown). Berikan warna merah untuk setosa, hijau untuk versicolor, biru untuk virginica, dan kuning untuk unknown
# * Sepal length dan petal width
# * Sepal width petal length
# * Sepal length dan petal width
# * Seal length dan petal length
#  <br>*Hint : gunakan perintah scatter dan operasi slicing pada numpy untuk mempermudah tugas anda*
# 6.	Jelaskan bagaimana karakter pengelompokan setiap kelas pada scatterplot
# 7.	Perhatikan data yang berjenis unknown. Jelaskan bagaimana cara meramal jenis data unknown
# 8.	Buatlah pararrel coordinat plot dari data yang berkelas setosa, versicolor, dan virginica. Berikan warna merah untuk setosa, hijau untuk versicolor, biru untuk virginica.
#  <br>*Hint gunakan perintah plot dan operasi slicing pada numpy untuk mempermudah tugas anda *
# 9.	Jelaskan bagaimana karakter pengelompokan setiap kelas pada scatterplot

# %%
import pandas as pd

from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

downloaded = drive.CreateFile({'id':"1xqXH7RWJPdmJAHM9sZzm4JvaTxB_A6n9"})
downloaded.GetContentFile('iris_mod2.xlsx')

# %%
downloaded
data = pd.read_excel('iris_mod2.xlsx') 
data.head(10)
# Out:
#    No  Petal_width  Petal_length  ...  Species_name  Unnamed: 6         Unnamed: 7
# 0   1          0.2           1.4  ...        Setosa         NaN  [0.2,1.4,3.5,5.1]
# 1   2          0.2           1.4  ...        Setosa         NaN    [0.2,1.4,3,4.9]
# 2   3          0.2           1.3  ...        Setosa         NaN  [0.2,1.3,3.2,4.7]
# 3   4          0.2           1.5  ...        Setosa         NaN  [0.2,1.5,3.1,4.6]
# 4   5          0.2           1.4  ...        Setosa         NaN    [0.2,1.4,3.6,5]
# 5   6          0.4           1.7  ...        Setosa         NaN  [0.4,1.7,3.9,5.4]
# 6   7          0.3           1.4  ...        Setosa         NaN  [0.3,1.4,3.4,4.6]
# 7   8          0.2           1.5  ...        Setosa         NaN    [0.2,1.5,3.4,5]
# 8   9          0.2           1.4  ...        Setosa         NaN  [0.2,1.4,2.9,4.4]
# 9  10          0.1           1.5  ...        Setosa         NaN  [0.1,1.5,3.1,4.9]
#
# [10 rows x 8 columns]

# %%
np_data = data.to_numpy()
np_data = np_data[:,1:6] #Remove un needed col (it will be just petal_width until species_name)

# %%
def get_species(kind: str):
  species_name_col = np_data[:,4]
  arr = np.where(species_name_col == kind)
  return np_data[arr][:,:4]

setosa      = get_species(' Setosa')
verginica   = get_species(' Verginica')
versicolor  = get_species(' Versicolor')
unknown     = get_species('unknown')

def get_col(species: np.ndarray, col):
  if col == 'pw':
    return species[:,0]
  elif col == 'pl':
    return species[:,1]
  elif col == 'sw':
    return species[:,2]
  elif col == 'sl':
    return species[:,3]
  else:
    return null

# %% [markdown]
# 5. Buatlah scatter plot yang menggunakan pasangan attribut berikut pada setiap kelas (termasuk unknown). Berikan warna merah untuk setosa, hijau untuk versicolor, biru untuk virginica, dan kuning untuk unknown

# %%
# ?di pisah tiap plot?
def soal_5(x, y, title):
  plt.title(title)
  plt.scatter(get_col(setosa, x), get_col(setosa, y), color = 'r')
  plt.scatter(get_col(versicolor, x), get_col(versicolor, y), color = 'g')
  plt.scatter(get_col(verginica, x), get_col(verginica, y), color = 'b')
  plt.scatter(get_col(unknown, x), get_col(unknown, y), color = 'y')
  plt.show()

# # plt.title("Sepal length dan petal width")
# soal_5('sl', 'pw', 'Sepal length dan petal width')
# # plt.title("Sepal width petal length")
# soal_5('sw', 'pl', 'Sepal width petal length')
# # plt.title("Sepal length dan petal width")
# soal_5('sl', 'pw', 'Sepal length dan petal width')
# # plt.title("Sepal length dan petal length")
# soal_5('sl','pl','Sepal length dan petal length')
# ptag.br(4)

fig, axs = plt.subplots(2, 2, figsize=(10, 10))
fig.suptitle('Representasi dalam sub plot')
def soal_5_subplot(x, y, title, pos):
  axs[pos[0],pos[1]].title.set_text(title)
  axs[pos[0],pos[1]].scatter(get_col(setosa, x), get_col(setosa, y), color = 'r', label='Setosa')
  axs[pos[0],pos[1]].scatter(get_col(versicolor, x), get_col(versicolor, y), color = 'g', label='Versicolor')
  axs[pos[0],pos[1]].scatter(get_col(verginica, x), get_col(verginica, y), color = 'b', label='Verginica')
  axs[pos[0],pos[1]].scatter(get_col(unknown, x), get_col(unknown, y), color = 'y', label='Unknown')
  axs[pos[0],pos[1]].legend()
soal_5_subplot('sl', 'pw', 'Sepal length dan petal width', [0,0])
soal_5_subplot('sw', 'pl', 'Sepal width petal length', [0,1])
soal_5_subplot('sl', 'pw', 'Sepal length dan petal width', [1,0])
soal_5_subplot('sl','pl','Sepal length dan petal length', [1,1])
plt.show()

# %% [markdown]
# 7. Perhatikan data yang berjenis unknown. Jelaskan bagaimana cara meramal jenis data unknown

# %% [markdown]
# 8. Buatlah pararrel coordinat plot dari data yang berkelas setosa, versicolor, dan virginica. Berikan warna merah untuk setosa, hijau untuk versicolor, biru untuk virginica.

# %%
features     = ["Petal Width", "Petal Length", "Sepal Width", "Sepal Length"]
name_resp    = ["Setosa", "Versicolor", "Verginica"]
responses    = [setosa,versicolor,verginica]
color        = ['r','g','b']


fig = plt.figure(figsize=(12,7))
ax = fig.add_axes([0,0,.7,.7]) # [left, bottom, width, height]
rect = fig.patch 
rect.set_facecolor('lightgoldenrodyellow') 
_ = 0
for response in responses:
  for key in range(len(response)):
    if(key != 0):
      plt.plot(range(len(features)), response[key,:],c=color[_])
    else:
      plt.plot(range(len(features)), response[key,:],c=color[_], label=name_resp[_] )
    ax.set_xticks(range(len(features)))
    ax.set_xticklabels(features)
  _ +=1
# plt.hist([x01, x02,x03], color=["lightcoral","lightskyblue","slategrey"], stacked=True, label=['Supressed','Active','Resolved'])
plt.grid()
plt.legend()
plt.show()

# %%
#@title psst.. its just memo
import matplotlib.ticker as ticker

#vectors to plot: 4D for this example
y1=[1,2.3,8.0,2.5,0.2]
y2=[1.5,1.7,2.2,2.9,1]
x=[1,2,3,8,100] # spines

fig,(ax,ax2,ax3,ax4) = plt.subplots(1, 4, sharey=False)

# plot the same on all the subplots
ax.plot(x,y1,'r-', x,y2,'b-')
ax2.plot(x,y1,'r-', x,y2,'b-')
ax3.plot(x,y1,'r-', x,y2,'b-')
ax4.plot(x,y1,'r-', x,y2,'b-')

# now zoom in each of the subplots 
ax.set_xlim([ x[0],x[1]])
ax2.set_xlim([ x[1],x[2]])
ax3.set_xlim([ x[2],x[3]])
ax4.set_xlim([ x[3],x[4]])


# set the x axis ticks 
for axx,xx in zip([ax,ax2,ax3,ax4],x[:-1]):
  axx.xaxis.set_major_locator(ticker.FixedLocator([xx]))
ax3.xaxis.set_major_locator(ticker.FixedLocator([x[-2],x[-1]]))  # the last one

for tick in ax4.yaxis.get_major_ticks():
  tick.label2On=True

plt.subplots_adjust(wspace=0)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:30: MatplotlibDeprecationWarning:
# The label2On function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use Tick.label2.set_visible instead.

# %%
#@title Sample Classification Using KNN to get Unknown value Features
import pandas as pd
col_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']
iris = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data', header=None, names=col_names)
iris.head()

# ### Terminology
# - **150 observations** (n=150): each observation is one iris flower
# - **4 features** (p=4): sepal length, sepal width, petal length, and petal width
# - **Response**: iris species
# - **Classification problem** since response is categorical

# ## Human learning on the iris dataset

# How did we (as humans) predict the species for iris flowers?
# 1. We looked for features that seemed to correlate with the response.
# 2. We created a set of rules (using those features) to predict the species of an unknown iris.

# More generally:
# 1. We observed that the different species had (somewhat) dissimilar measurements.
# 2. We predicted the species for an unknown iris by:
#     - Looking for irises in the data with similar measurements
#     - Assuming that our unknown iris is the same species as those similar irises

# create a custom colormap
from matplotlib.colors import ListedColormap
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

# map each iris species to a number
iris['species_num'] = iris.species.map({'Iris-setosa':0, 'Iris-versicolor':1, 'Iris-virginica':2})

# create a scatter plot of PETAL LENGTH versus PETAL WIDTH and color by SPECIES
iris.plot(kind='scatter', x='petal_length', y='petal_width', c='species_num', colormap=cmap_bold)

# create a scatter plot of SEPAL LENGTH versus SEPAL WIDTH and color by SPECIES
iris.plot(kind='scatter', x='sepal_length', y='sepal_width', c='species_num', colormap=cmap_bold)

iris.head()

# store feature matrix in "X"
feature_cols = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
X = iris[feature_cols]

X = iris.drop(['species', 'species_num'], axis=1)
X = iris.loc[:, 'sepal_length':'petal_width']
X = iris.iloc[:, 0:4]

y = iris.species_num

from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=1)
# print(knn)

knn.fit(X, y)      #Menyesuaikan model dengan data training

X_new = [[3, 5, 4, 2], [5, 4, 3, 2]]
knn.predict(X_new) #Return berupa array numpy hasil prediksi

knn = KNeighborsClassifier(n_neighbors=5) # inisiasi dengan K= 5
knn.fit(X, y)      #Menyesuaikan model dengan data training
knn.predict(X_new)

knn.predict_proba(X_new)
# Out:
# array([[0. , 0.8, 0.2],
#        [0. , 1. , 0. ]])
